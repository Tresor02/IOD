# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 4.1.1 Linear Regression

# %% [markdown]
# ## Prediction of House Price Using Linear Regression

# %% [markdown]
# ### Data
#
# The Sacramento real estate transactions file is a list of 985 real estate transactions in the Sacramento area reported over a five-day period, as reported by the Sacramento Bee.

# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### 1. Explore Data

# %% [markdown]
# Perform EDA on this dataset. Use what you have learned so far. Be creative. List all your findings.

# %%
# Read CSV
house_csv = "/Users/tresornoel/Desktop/IOD/DATA/Sacramento_transactions.csv"
df=pd.read_csv(house_csv)

# %%
#checking our datase by using head, tail or sample
df.sample(10)
# Out:
#                  street             city    zip state  beds  baths  sq__ft  \
# 524      2743 DEAKIN PL  EL DORADO HILLS  95762    CA     3      2       0
# 637         4904 J PKWY       SACRAMENTO  95823    CA     3      2    1400
# 188   3174 NORTHVIEW DR       SACRAMENTO  95833    CA     3      1    1080
# 44        7315 KOALA CT  NORTH HIGHLANDS  95660    CA     4      2    1587
# 19      113 LEEWILL AVE        RIO LINDA  95673    CA     3      2    1356
# 612        5821 64TH ST       SACRAMENTO  95824    CA     2      1     861
# 831    1124 PERKINS WAY       SACRAMENTO  95818    CA     2      1    1304
# 617   6063 LAND PARK DR       SACRAMENTO  95822    CA     2      1     800
# 717  9176 SAGE GLEN WAY        ELK GROVE  95758    CA     3      2    1338
# 42         8718 ELK WAY        ELK GROVE  95624    CA     3      2    1056
#
#             type                     sale_date   price   latitude   longitude
# ...

# %%
#shape of our dataset
df.shape
# Out:
# (985, 12)

# %%
#havong a look at the datatypes we have
df.dtypes
# Out:
# street        object
# city          object
# zip            int64
# state         object
# beds           int64
# baths          int64
# sq__ft         int64
# type          object
# sale_date     object
# price          int64
# latitude     float64
# longitude    float64
# dtype: object

# %%
#checking our columns
df.columns
# Out:
# Index(['street', 'city', 'zip', 'state', 'beds', 'baths', 'sq__ft', 'type',
#        'sale_date', 'price', 'latitude', 'longitude'],
#       dtype='object')

# %%
#To check if there's any missing values
df.isnull().sum()
# Out:
# street       0
# city         0
# zip          0
# state        0
# beds         0
# baths        0
# sq__ft       0
# type         0
# sale_date    0
# price        0
# latitude     0
# longitude    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   street     985 non-null    object
#  1   city       985 non-null    object
#  2   zip        985 non-null    int64
#  3   state      985 non-null    object
#  4   beds       985 non-null    int64
#  5   baths      985 non-null    int64
#  6   sq__ft     985 non-null    int64
#  7   type       985 non-null    object
#  8   sale_date  985 non-null    object
#  9   price      985 non-null    int64
#  10  latitude   985 non-null    float64
#  11  longitude  985 non-null    float64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 92.5+ KB

# %%
#having an overview of our numerical values and trying to find any similarity or patterns
df.describe().T
# Out:
#            count           mean            std           min            25%  \
# zip        985.0   95750.697462      85.176072  95603.000000   95660.000000
# beds       985.0       2.911675       1.307932      0.000000       2.000000
# baths      985.0       1.776650       0.895371      0.000000       1.000000
# sq__ft     985.0    1314.916751     853.048243      0.000000     952.000000
# price      985.0  234144.263959  138365.839085   1551.000000  145000.000000
# latitude   985.0      38.607732       0.145433     38.241514      38.482717
# longitude  985.0    -121.355982       0.138278   -121.551704    -121.446127
#
#                      50%            75%            max
# zip         95762.000000   95828.000000   95864.000000
# beds            3.000000       4.000000       8.000000
# baths           2.000000       2.000000       5.000000
# sq__ft       1304.000000    1718.000000    5822.000000
# price      213750.000000  300000.000000  884790.000000
# ...

# %%
#Converting the 'sale_date' column type from object to datetime
df['sale_date'] = pd.to_datetime(df['sale_date'])
# Out:
# /var/folders/xg/jbqtrl9j5550jl9tl03n45dh0000gn/T/ipykernel_51811/1025330868.py:2: FutureWarning: Parsed string "Wed May 21 00:00:00 EDT 2008" included an un-recognized timezone "EDT". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df['sale_date'] = pd.to_datetime(df['sale_date'])

# %%
#verifying if the data type has been converted
df.dtypes
# Out:
# street               object
# city                 object
# zip                   int64
# state                object
# beds                  int64
# baths                 int64
# sq__ft                int64
# type                 object
# sale_date    datetime64[ns]
# price                 int64
# latitude            float64
# longitude           float64
# dtype: object

# %%
#checking our dataframe after conversion
df.tail()
#sale_date ?? with no day of the week??
# Out:
#                   street             city    zip state  beds  baths  sq__ft  \
# 980   9169 GARLINGTON CT       SACRAMENTO  95829    CA     4      3    2280
# 981      6932 RUSKUT WAY       SACRAMENTO  95823    CA     3      2    1477
# 982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610    CA     3      2    1216
# 983     8304 RED FOX WAY        ELK GROVE  95758    CA     4      2    1685
# 984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762    CA     3      2    1362
#
#             type  sale_date   price   latitude   longitude
# 980  Residential 2008-05-15  232425  38.457679 -121.359620
# 981  Residential 2008-05-15  234000  38.499893 -121.458890
# 982  Residential 2008-05-15  235000  38.708824 -121.256803
# 983  Residential 2008-05-15  235301  38.417000 -121.397424
# 984  Residential 2008-05-15  235738  38.655245 -121.075915

# %%
# # import the library
# import folium
# import pandas as pd

# # Make an empty map
# # 37.76, -122.45 is the initial location of SF, USA
# m = folium.Map(location=[38.575764, -121.478851], tiles="Mapbox Bright", zoom_start=10)

# # I can add circle/marker one by one on the map
# for i in range(0, len(data.head(1000))):b
# folium.Marker(location=[data.iloc[i]['latitude'], data.iloc[i]['longitude']]).add_to(m)

# display(m)

# %%
sns.histplot
# Out:
# <function seaborn.distributions.histplot(data=None, *, x=None, y=None, hue=None, weights=None, stat='count', bins='auto', binwidth=None, binrange=None, discrete=None, cumulative=False, common_bins=True, common_norm=True, multiple='layer', element='bars', fill=True, shrink=1, kde=False, kde_kws=None, line_kws=None, thresh=0, pthresh=None, pmax=None, cbar=False, cbar_ax=None, cbar_kws=None, palette=None, hue_order=None, hue_norm=None, color=None, log_scale=None, legend=True, ax=None, **kwargs)>

# %%
#ploting a box plot of city vs price to check which city has the most/least expensive houses
plt.figure(figsize = (12,10))
sns.boxplot(x = 'city', y = 'price', data = df, palette = 'Set2')
plt.title('boxplot of city by price')
plt.xlabel('city')
plt.ylabel('price')
plt.xticks(rotation= 75)
plt.grid(True)
# Out:
# /var/folders/xg/jbqtrl9j5550jl9tl03n45dh0000gn/T/ipykernel_51811/3698542286.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'city', y = 'price', data = df, palette = 'Set2')

# %%
#Trying to plot the mean  price per city to have a clear visualizatio
mean_price_per_city = df.groupby('city')['price'].mean().reset_index()

# Plotting the average house price by city
plt.figure(figsize=(12, 6))
sns.barplot(x='city', y='price', data=mean_price_per_city,palette = 'Set2')
plt.xticks(rotation=75)
plt.title('Average House Price by city')
plt.show()
# Out:
# /var/folders/xg/jbqtrl9j5550jl9tl03n45dh0000gn/T/ipykernel_51811/2184655954.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='city', y='price', data=mean_price_per_city,palette = 'Set2')

# %% [markdown]
# in the boxplot above we just observed that the city of granite bay has the most expensive houses while lincoln has the least expensive houses
# Sacramento has most outliers

# %%
#we want to check how is the sq_feet correlated to the house price by plotting a scatter plot
plt.scatter(df['sq__ft'],df[ 'price'], color = 'blue', alpha = 0.5, marker = 'o')
plt.xlabel('sq__ft')
plt.ylabel('price')
plt.title('Scatterplot sq feet vs price')
# Out:
# Text(0.5, 1.0, 'Scatterplot sq feet vs price')

# %% [markdown]
# in the scatterplot sq__ft vs price we can see that theres a correlation between the square feet of a house with the price of a house

# %%
plt.scatter(df['beds'],df[ 'price'], color = 'blue', alpha = 0.5, marker = 'o')
plt.xlabel('beds')
plt.ylabel('price')
plt.title('Scatterplot beds vs price')
# Out:
# Text(0.5, 1.0, 'Scatterplot beds vs price')

# %%
plt.scatter(df['baths'],df[ 'price'], color = 'blue', alpha = 0.5, marker = 'o')
plt.xlabel('baths')
plt.ylabel('price')
plt.title('Scatterplot baths vs price')
# Out:
# Text(0.5, 1.0, 'Scatterplot baths vs price')

# %% [markdown]
# the scatter plot above indicates that there's a correlation between the number of baths in a house with the price of the house

# %%
print(df['type'].unique())
print(df['zip'].unique())
# Out:
# ['Residential' 'Condo' 'Multi-Family' 'Unkown']
# [95838 95823 95815 95824 95841 95842 95820 95670 95673 95822 95621 95833
#  95660 95834 95843 95832 95827 95828 95758 95626 95825 95835 95624 95632
#  95826 95608 95662 95630 95829 95655 95757 95742 95726 95818 95762 95831
#  95683 95693 95814 95635 95864 95817 95628 95682 95648 95667 95610 95722
#  95816 95678 95747 95819 95811 95677 95765 95603 95661 95650 95821 95623
#  95663 95746 95631 95619 95614 95690 95633 95691]

# %%
grouped_type = df.groupby('type')['price'].mean()
grouped_zip = df.groupby('zip')['price'].mean()
grouped_type = grouped_type.reset_index()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='type', y='price',data= grouped_type)
plt.title('grouped Type vs mean price ')
plt.xlabel('type')
plt.ylabel('price')
plt.show()

# %% [markdown]
# ### 2. Predict Price

# %% [markdown]
# We are going to predict `price` from available information.

# %% [markdown]
# #### 2.1 What is the Target Variable? Why?

# %% [markdown]
# # ANSWER
# the target variable is the ' price ' because we want to predict the price of the houses in sacramento

# %% [markdown]
# #### 2.2 List all possible variables which might be Predictor variable.

# %%
# ANSWER

## beds
## baths
## sqft
## Type

# %% [markdown]
# #### 2.3 Find correlation between variables
#
# Find correlation between variables. Which is the best predictor? Why? State your reason.

# %%
# ANSWER
numeric_df = df.select_dtypes(include=[float, int])
numeric_df.corr()

### sq_ft is the best predictor.
### sqft is continuous and has moderate relationship with beds, baths
# Out:
#                 zip      beds     baths    sq__ft     price  latitude  \
# zip        1.000000  0.125319  0.069165  0.130108 -0.093353 -0.290389
# beds       0.125319  1.000000  0.839650  0.684041  0.342024 -0.291307
# baths      0.069165  0.839650  1.000000  0.665690  0.416208 -0.235792
# sq__ft     0.130108  0.684041  0.665690  1.000000  0.333897 -0.383274
# price     -0.093353  0.342024  0.416208  0.333897  1.000000 -0.039573
# latitude  -0.290389 -0.291307 -0.235792 -0.383274 -0.039573  1.000000
# longitude -0.539904 -0.053993  0.016582 -0.177742  0.284485  0.387925
# y_mean          NaN       NaN       NaN       NaN       NaN       NaN
# Yhat       0.130108  0.684041  0.665690  1.000000  0.333897 -0.383274
#
#            longitude  y_mean      Yhat
# zip        -0.539904     NaN  0.130108
# beds       -0.053993     NaN  0.684041
# baths       0.016582     NaN  0.665690
# sq__ft     -0.177742     NaN  1.000000
# price       0.284485     NaN  0.333897
# ...

# %% [markdown]
# #### 2.4 What is the simplest way to predict price
#
# So we have information for 985 houses. What is the easiest way to predict the price of a house using the price values alone? (Hint: it is a simple calculation)

# %%
# ANSWER
## Mean of Price
df['y_mean'] = df['price'].mean()

# %% [markdown]
# #### 2.5 Find Residuals
#
# Find difference between actual value and predicted value. Use absolute value.

# %%
# ANSWER
res = abs(df['price'] - df['y_mean'])
res
# Out:
# 0      174922.263959
# 1      165932.263959
# 2      165264.263959
# 3      164837.263959
# 4      152244.263959
#            ...
# 980      1719.263959
# 981       144.263959
# 982       855.736041
# 983      1156.736041
# 984      1593.736041
# Length: 985, dtype: float64

# %% [markdown]
# #### 2.6  Predict Using Linear Regression
#
# [Simple Linear Regression](https://en.wikipedia.org/wiki/Simple_linear_regression#Fitting_the_regression_line)
#
# ### $$\hat{y} = \beta_0 + \beta_1 x$$
#
# > ### $$ \beta_1 = \frac{\sum_{i=1}^n (y_i - \bar{y} ) (x_i - \bar{x} )}{\sum_{i=1}^n (x_i - \bar{x})^2} $$
#
# and
#
# > ### $$ \beta_0 = \bar{y} - \beta_1\bar{x} $$
#
# Given variables:
# - $\bar{y}$ : the sample mean of observed values $Y$
# - $\bar{x}$ : the sample mean of observed values $X$

# %% [markdown]
# ##### 2.7 Define X, Y
#
# - X = Predictor Variable
# - Y = Target Variable

# %%
# ANSWER
X = df['sq__ft']
Y = df['price']

# %% [markdown]
# ##### 2.7.A Calculate beta_1
#
#  ### $$ \beta_1 = \frac{\sum_{i=1}^n (y_i - \bar{y} ) (x_i - \bar{x} )}{\sum_{i=1}^n (x_i - \bar{x})^2} $$

# %%
# ANSWER
def calculate_beta_1(X, Y):
    Xbar = X.mean()
    Ybar = Y.mean()

    n = np.sum((Y - Ybar) * (X - Xbar))
    d = np.sum(np.square(X - Xbar))

    beta_1 = n/d

    return beta_1

# %%
beta_1 = calculate_beta_1(X, y)
beta_1
# Out:
# 54.158639688530755

# %% [markdown]
# ##### 2.7.B Calculate beta_0

# %% [markdown]
# ### $$ \beta_0 = \bar{y} - \beta_1\bar{x} $$

# %%
# ANSWER
def calculate_beta_0(X, Y):

    Xbar = X.mean()
    Ybar = Y.mean()

    beta_0 = Ybar - calculate_beta_1(X, Y) * Xbar

    return beta_0

# %%
beta_0 = calculate_beta_0(X, y)
beta_0
# Out:
# 162930.16140699777

# %% [markdown]
# ##### 2.7.C Find Yhat (Predicted Value Using Beta 0 and Beta 1)

# %% [markdown]
# ### $$\hat{y} = \beta_0 + \beta_1 x$$

# %%
# ANSWER
def calculate_yhat(x, b0, b1):
    return b0 + b1 * x

# %%
Yhat = calculate_yhat(X, beta_0, beta_1)
Yhat
# Out:
# 0      208206.784187
# 1      226133.293924
# 2      206040.438599
# 3      209073.322422
# 4      206094.597239
#            ...
# 980    286411.859897
# 981    242922.472227
# 982    228787.067268
# 983    254187.469282
# 984    236694.228663
# Name: sq__ft, Length: 985, dtype: float64

# %% [markdown]
# ##### 2.7.D Find Residuals

# %% [markdown]
# ### $$ \text{residual}_i = y_i - \hat{y}_i$$

# %%
# ANSWER
def calculate_residual(Y, Yhat):
    res = Y - Yhat
    return res

# %%
resi = calculate_residual(Y, Yhat)
abs(resi)
# Out:
# 0      148984.784187
# 1      157921.293924
# 2      137160.438599
# 3      139766.322422
# 4      124194.597239
#            ...
# 980     53986.859897
# 981      8922.472227
# 982      6212.932732
# 983     18886.469282
# 984       956.228663
# Length: 985, dtype: float64

# %% [markdown]
# ##### 2.7.E Find R-Squared
#
# The coefficient $R^2$ is defined as $$ R^2 = 1 - \frac{SS_{res}}{SS_{tot}} $$, where $$ SS_{res} $$ is the residual sum of squares $$ SS_{res} = \sum_{i=1}^n \left(y_i - \hat{y}_i\right)^2 $$ and $$ SS_{res} $$ is the total sum of squares $$ SS_{tot} = \sum_{i=1}^n \left(y_i - \bar{y}\right)^2 $$
#
# The best possible score is 1.0 and it can be negative (because the model can be arbitrarily worse).
#
# **Write a function to calculate R- Square value.**

# %% [markdown]
# The total sum of squares:
#
# ### $$ SS_{tot} = \sum_{i=1}^n \left(y_i - \bar{y}\right)^2 $$
#
# The residual sum of squares:
#
# ### $$ SS_{res} = \sum_{i=1}^n \left(y_i - \hat{y}_i\right)^2 $$
#
# $R^2$:
#
# ### $$ R^2 = 1 - \frac{SS_{res}}{SS_{tot}} $$

# %%
# ANSWER
def calculate_total_sum_of_square(Y):
    Ybar = np.mean(Y)
    SStot = np.square(Y - Ybar)
    SStot = np.sum(SStot)
    return SStot

# %%
def calculate_residual_sum_of_square(Y, Yhat):
    SSres = np.square(Y - Yhat)
    SSres = np.sum(SSres)
    return SSres

# %%
def calculate_r_square(Y, Yhat):
    SStot = calculate_total_sum_of_square(Y)
    SSres = calculate_residual_sum_of_square(Y, Yhat)
    Rsquare = 1 - (SSres/SStot)
    return Rsquare

# %%
calculate_r_square(Y, np.mean(Y))
# Out:
# 0.0

# %%
calculate_r_square(Y, calculate_yhat(X, beta_0, beta_1))
# Out:
# 0.11148717682951459

# %% [markdown]
# ##### 2.7.F [BONUS] Draw Plot of Predicted Line

# %%
def draw_plot(X, Y, Ymean):
    ### Plot the data
    # create a figure
    fig = plt.figure(figsize=(15,7))
    # get the axis of that figure
    ax = plt.gca()

    # plot a scatter plot on it with our data
    ax.scatter(X, Y, c='b')
    ax.plot(X, Ymean, color='r');

    plt.show();

# %%
# ANSWER

draw_plot(X, Y, Yhat)

# %% [markdown]
# ##### 2.7.G [BONUS] Draw Plot of Predicted Line With Residuals

# %%
# ANSWER
df['Yhat'] = Yhat

# %%
# create a figure
fig = plt.figure(figsize=(15,7))
fig.set_figheight(8)
fig.set_figwidth(15)

# get the axis
ax = fig.gca()

# plot it
ax.scatter(x=X, y=Y, c='b')
ax.plot(X, Yhat, color='r');

# iterate over predictions
for _, row in df.iterrows():
    plt.plot((row['sq__ft'], row['sq__ft']), (row['price'], row['Yhat']), 'g-')

# %% [markdown]
# ### 3. Predict House Price
#
# Let's assume we have information of following house:
#
# - street:	1140 EDMONTON DR
# - city:	SACRAMENTO
# - zip:	95833
# - state:	CA
# - beds:	3
# - baths:	2
# - sq__ft:	1204
# - type:	Residential
#
# **Predict the price of this house.**

# %%
# ANSWER
xpred = 1204
xpred
# Out:
# 1204

# %%
beta_0
# Out:
# 162930.16140699777

# %%
beta_1
# Out:
# 54.158639688530755

# %%
Ypred = beta_1 * xpred + beta_0
Ypred
# Out:
# 228137.1635919888

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2024 Institute of Data
#
#
# ---
#
#
#
# ---
